# %% [markdown]
# KMeans clustering

# %%
import pandas as pd

# %%
df = pd.read_csv('dogs.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of                    breed  height  weight
# 0          Border Collie      20      45
# 1         Boston Terrier      16      20
# 2       Brittany Spaniel      18      35
# 3            Bullmastiff      27     120
# 4              Chihuahua       8       8
# 5        German Shepherd      25      78
# 6       Golden Retriever      23      70
# 7             Great Dane      32     160
# 8   Portuguese Water Dog      21      50
# 9        Standard Poodle      19      65
# 10     Yorkshire Terrier       6       7>

# %%
X = df.drop('breed', axis=1)

# %%
X.head
# Out:
# <bound method NDFrame.head of     height  weight
# 0       20      45
# 1       16      20
# 2       18      35
# 3       27     120
# 4        8       8
# 5       25      78
# 6       23      70
# 7       32     160
# 8       21      50
# 9       19      65
# 10       6       7>

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X)
# Out:
# MinMaxScaler()

# %%
X = scaler.transform(X)
X[0]
# Out:
# array([0.53846154, 0.24836601])

# %%
X = pd.DataFrame(X, columns=df.columns[1:])

# %%
X.head
# Out:
# <bound method NDFrame.head of       height    weight
# 0   0.538462  0.248366
# 1   0.384615  0.084967
# 2   0.461538  0.183007
# 3   0.807692  0.738562
# 4   0.076923  0.006536
# 5   0.730769  0.464052
# 6   0.653846  0.411765
# 7   1.000000  1.000000
# 8   0.576923  0.281046
# 9   0.500000  0.379085
# 10  0.000000  0.000000>

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=2)

# %%
kmeans.fit(X)
# Out:
# KMeans(n_clusters=2)

# %%
kmeans.cluster_centers_
# Out:
# array([[0.79807692, 0.65359477],
#        [0.36263736, 0.16900093]])

# %%
kmeans.inertia_
# Out:
# 0.732128510026434

# %%
kmeans.labels_
# Out:
# array([1, 1, 1, 0, 1, 0, 0, 0, 1, 1, 1])

# %%
from sklearn.metrics import silhouette_score

# %%
silhouette_score(X, kmeans.labels_)
# Out:
# 0.4222806427824013

# %% [markdown]
# Agglomerative hierarchy Clustering

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
model = AgglomerativeClustering(linkage='average', n_clusters=3)

# %%
AgglomerativeClustering?

# %%
model.fit(X)
# Out:
# AgglomerativeClustering(linkage='average', n_clusters=3)

# %%
model.labels_
# Out:
# array([1, 1, 1, 0, 2, 1, 1, 0, 1, 1, 2], dtype=int64)

# %%
model.children_
# Out:
# array([[ 0,  8],
#        [ 4, 10],
#        [ 5,  6],
#        [ 1,  2],
#        [ 9, 11],
#        [14, 15],
#        [13, 16],
#        [ 3,  7],
#        [12, 17],
#        [18, 19]])

# %%
silhouette_score(X, model.labels_)
# Out:
# 0.5813924452451538

# %% [markdown]
# DBSCAN Clustering

# %%
from sklearn.cluster import DBSCAN

# %%
model = DBSCAN(e)
