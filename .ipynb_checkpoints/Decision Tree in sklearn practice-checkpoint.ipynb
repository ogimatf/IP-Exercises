# %% [markdown]
# Simple decision tree on Iris database

# %%
import pandas as pd

# %%
pd.Series([1,3,5,7])
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# dtype: int64

# %%
pd.Series?

# %%
df = pd.read_csv('iris.csv')
df.describe()
df.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Species', axis=1)
y = df['Species']

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7)

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()

model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9111111111111111

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 7,  0,  0],
#        [ 0, 18,  0],
#        [ 0,  4, 16]], dtype=int64)

# %% [markdown]
# Some pandas functions

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
df = pd.DataFrame([[1,2,3],[4,5,6]], columns=['ime','prezime','godina'])

# %%
pd.DataFrame?

# %%
df.iloc[0:-1]
# Out:
#    ime  prezime  godina
# 0    1        2       3

# %%
df[df['godina'] > 25]
# Out:
# Empty DataFrame
# Columns: [ime, prezime, godina]
# Index: []

# %%
df = pd.read_excel('skupV1.xlsx')

# %%
df.head
# Out:
# <bound method NDFrame.head of     id    name  age gender
# 0    1     Ana   20      F
# 1    2   Marko    3      M
# 2    3  Veljko   50      M
# 3    4     Ana   18      F
# 4    5   Milan   10    NaN
# 5    6   Vanja   65      F
# 6    7    Mila   80      F
# 7    8   Goran   30    NaN
# 8    9  Jovana  250      F
# 9   10   Ivana   16      F
# 10  11     NaN   25      F
# 11  12           36      M>

# %%
df.describe()
# Out:
#               id         age
# count  12.000000   12.000000
# mean    6.500000   50.250000
# std     3.605551   66.901726
# min     1.000000    3.000000
# 25%     3.750000   17.500000
# 50%     6.500000   27.500000
# 75%     9.250000   53.750000
# max    12.000000  250.000000

# %%
df.dropna()
# Out:
#     id    name  age gender
# 0    1     Ana   20      F
# 1    2   Marko    3      M
# 2    3  Veljko   50      M
# 3    4     Ana   18      F
# 5    6   Vanja   65      F
# 6    7    Mila   80      F
# 8    9  Jovana  250      F
# 9   10   Ivana   16      F
# 11  12           36      M

# %%
df.shape
# Out:
# (12, 4)

# %%
df.isna().any()
# Out:
# id        False
# name       True
# age       False
# gender     True
# dtype: bool

# %%
df.corr()
# Out:
#            id       age
# id   1.000000  0.258348
# age  0.258348  1.000000

# %%
df.isna().any()
# Out:
# id        False
# name       True
# age       False
# gender     True
# dtype: bool

# %% [markdown]
# Decision Tree tinkering with iris.csv

# %%
df = pd.read_csv('iris.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
feature_names = model.classes_

# %%
model.feature_importances_
# Out:
# array([0.        , 0.04336735, 0.34124395, 0.6153887 ])

# %%
from sklearn.tree import plot_tree

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize =(10, 10))

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {'criterion' : ['gini', 'entropy'],
          'max_depth' : [2,3,4]}

# %%
model = GridSearchCV(DecisionTreeClassifier(), param_grid = params, scoring = 'accuracy', cv = 5, verbose = 4)

# %%
GridSearchCV?

# %%
model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5] END ....................criterion=gini, max_depth=2; total time=   0.0s
# [CV 2/5] END ....................criterion=gini, max_depth=2; total time=   0.0s
# [CV 3/5] END ....................criterion=gini, max_depth=2; total time=   0.0s
# [CV 4/5] END ....................criterion=gini, max_depth=2; total time=   0.0s
# [CV 5/5] END ....................criterion=gini, max_depth=2; total time=   0.0s
# [CV 1/5] END ....................criterion=gini, max_depth=3; total time=   0.0s
# [CV 2/5] END ....................criterion=gini, max_depth=3; total time=   0.0s
# [CV 3/5] END ....................criterion=gini, max_depth=3; total time=   0.0s
# [CV 4/5] END ....................criterion=gini, max_depth=3; total time=   0.0s
# [CV 5/5] END ....................criterion=gini, max_depth=3; total time=   0.0s
# [CV 1/5] END ....................criterion=gini, max_depth=4; total time=   0.0s
# ...

# %%
model.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
model.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 4}

# %%
model.best_score_
# Out:
# 0.9428571428571428
