# %% [markdown]
# Categorical Naive Bayes practice using Ordinal Encoder

# %%
import pandas as pd

# %%
df = pd.read_csv('balloons.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of      color   size      act    age inflated
# 0   YELLOW  SMALL  STRETCH  ADULT        T
# 1   YELLOW  SMALL  STRETCH  ADULT        T
# 2   YELLOW  SMALL  STRETCH  CHILD        F
# 3   YELLOW  SMALL      DIP  ADULT        F
# 4   YELLOW  SMALL      DIP  CHILD        F
# ..     ...    ...      ...    ...      ...
# 71  PURPLE  SMALL      DIP  CHILD        F
# 72  PURPLE  LARGE  STRETCH  ADULT        F
# 73  PURPLE  LARGE  STRETCH  CHILD        F
# 74  PURPLE  LARGE      DIP  ADULT        F
# 75  PURPLE  LARGE      DIP  CHILD        F
#
# [76 rows x 5 columns]>

# %%
df.shape
# Out:
# (76, 5)

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder()

# %%
X = df[df.columns[:-1]]

# %%
X.head
# Out:
# <bound method NDFrame.head of      color   size      act    age
# 0   YELLOW  SMALL  STRETCH  ADULT
# 1   YELLOW  SMALL  STRETCH  ADULT
# 2   YELLOW  SMALL  STRETCH  CHILD
# 3   YELLOW  SMALL      DIP  ADULT
# 4   YELLOW  SMALL      DIP  CHILD
# ..     ...    ...      ...    ...
# 71  PURPLE  SMALL      DIP  CHILD
# 72  PURPLE  LARGE  STRETCH  ADULT
# 73  PURPLE  LARGE  STRETCH  CHILD
# 74  PURPLE  LARGE      DIP  ADULT
# 75  PURPLE  LARGE      DIP  CHILD
#
# [76 rows x 4 columns]>

# %%
y = df.iloc[:,-1]

# %%
y.head
# Out:
# <bound method NDFrame.head of 0     T
# 1     T
# 2     F
# 3     F
# 4     F
#      ..
# 71    F
# 72    F
# 73    F
# 74    F
# 75    F
# Name: inflated, Length: 76, dtype: object>

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=13, stratify=y)

# %%
X_train.head
# Out:
# <bound method NDFrame.head of      color   size      act    age
# 66  YELLOW  LARGE      DIP  ADULT
# 21  YELLOW  SMALL  STRETCH  CHILD
# 12  PURPLE  SMALL  STRETCH  CHILD
# 25  YELLOW  LARGE  STRETCH  ADULT
# 46  YELLOW  LARGE      DIP  ADULT
# 23  YELLOW  SMALL      DIP  CHILD
# 34  PURPLE  SMALL      DIP  CHILD
# 73  PURPLE  LARGE  STRETCH  CHILD
# 26  YELLOW  LARGE  STRETCH  CHILD
# 36  PURPLE  LARGE  STRETCH  CHILD
# 20  YELLOW  SMALL  STRETCH  ADULT
# 0   YELLOW  SMALL  STRETCH  ADULT
# 65  YELLOW  LARGE  STRETCH  CHILD
# 54  PURPLE  LARGE      DIP  ADULT
# 8   YELLOW  LARGE      DIP  ADULT
# 71  PURPLE  SMALL      DIP  CHILD
# 7   YELLOW  LARGE  STRETCH  CHILD
# 11  PURPLE  SMALL  STRETCH  ADULT
# 55  PURPLE  LARGE      DIP  CHILD
# 50  PURPLE  SMALL      DIP  ADULT
# 32  PURPLE  SMALL      DIP  ADULT
# 9   YELLOW  LARGE      DIP  CHILD
# 35  PURPLE  LARGE  STRETCH  ADULT
# 22  YELLOW  SMALL      DIP  ADULT
# 49  PURPLE  SMALL  STRETCH  CHILD
# 43  YELLOW  SMALL      DIP  CHILD
# 75  PURPLE  LARGE      DIP  CHILD
# 13  PURPLE  SMALL      DIP  ADULT
# 63  YELLOW  SMALL      DIP  CHILD
# 61  YELLOW  SMALL  STRETCH  CHILD
# 6   YELLOW  LARGE  STRETCH  ADULT
# 58  YELLOW  SMALL      DIP  ADULT
# 39  PURPLE  LARGE      DIP  CHILD
# 40  YELLOW  SMALL  STRETCH  ADULT
# 3   YELLOW  SMALL      DIP  ADULT
# 72  PURPLE  LARGE  STRETCH  ADULT
# 30  PURPLE  SMALL  STRETCH  ADULT
# 29  YELLOW  LARGE      DIP  CHILD
# 27  YELLOW  LARGE      DIP  ADULT
# 47  YELLOW  LARGE      DIP  CHILD
# 10  PURPLE  SMALL  STRETCH  ADULT
# 67  YELLOW  LARGE      DIP  CHILD
# 60  YELLOW  SMALL  STRETCH  ADULT
# 64  YELLOW  LARGE  STRETCH  ADULT
# 1   YELLOW  SMALL  STRETCH  ADULT
# 5   YELLOW  LARGE  STRETCH  ADULT
# 48  PURPLE  SMALL  STRETCH  ADULT
# 28  YELLOW  LARGE      DIP  CHILD
# 2   YELLOW  SMALL  STRETCH  CHILD
# 14  PURPLE  SMALL      DIP  CHILD>

# %%
oe.fit(X_train)
# Out:
# OrdinalEncoder()

# %%
X_train = oe.transform(X_train)

# %%
X_test = oe.transform(X_test)

# %%
from sklearn.naive_bayes import CategoricalNB

# %%
model = CategoricalNB()

# %%
X_train[0]
# Out:
# array([1., 0., 0., 0.])

# %%
model.fit(X_train, y_train)
# Out:
# CategoricalNB()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[12,  2],
#        [ 2, 10]], dtype=int64)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8461538461538461

# %%
CategoricalNB?
